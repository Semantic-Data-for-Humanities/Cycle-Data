# %%
import pandas as pd
import os

# %%
csd = os.getcwd()
print(csd)
# Out:
# /home/francesco/shared_files/python_notebooks/SD_for_HSS/Cycle-Data

# %%
os.chdir('/home/francesco/shared_files/python_notebooks/SD_for_HSS/Cycle-Data')

# %%
tt = pd.read_csv('./data/slave-voyages_trans-atlantic-db.csv')
# Out:
# /tmp/ipykernel_782625/1517873420.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   tt = pd.read_csv('./data/slave-voyages_trans-atlantic-db.csv')

# %%
tt.head()
# Out:
#                             Captain's name  Crew deaths during voyage  \
# 0                        Velde, Daniel ter                        NaN
# 1  Hoeven, Jan van der<br/> Wenman, Roelof                        NaN
# 2                                      NaN                        NaN
# 3                           Scheij, Pieter                        NaN
# 4         Stoop, Pieter<br/> Crans, Pieter                        NaN
#
#    Crew at first landing of captives  Crew at voyage outset  \
# 0                                NaN                   54.0
# 1                                NaN                   23.0
# 2                                NaN                    NaN
# 3                                NaN                    NaN
# 4                                NaN                    NaN
#
#   Date vessel departed with captives Date vessel departed for homeport  \
# 0               1732-09-03T00:00:00Z              1733-04-24T00:00:00Z
# ...
